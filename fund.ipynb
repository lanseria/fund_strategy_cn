# %%
# %pip install akshare backtrader quantstats-reloaded pandas numpy ipython
# Out:
# Looking in indexes: https://mirror.nju.edu.cn/pypi/web/simple
# Collecting akshare
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/8b/1d/33cebc2b7a34b73e457125e358b99bfa178c796c72f7962f9d2af15abadd/akshare-1.17.5-py3-none-any.whl (1.1 MB)
# Collecting backtrader
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/f3/ef/328c6ec332435f63b3e18febd263686b8ba07e990676a862cc8522ba38f5/backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
# Collecting quantstats-reloaded
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/64/6f/7f3abe4a129a0bc608d27f390180cd43a857b17660e4c210da0d3d3a88f4/quantstats_reloaded-0.1.0-py3-none-any.whl (52 kB)
# Collecting pandas
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/05/01/0c8785610e465e4948a01a059562176e4c8088aa257e2e074db868f86d4e/pandas-2.3.0-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 12.0 MB/s eta 0:00:0000:010:01
# Collecting numpy
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/64/d5/06d4bb31bb65a1d9c419eb5676173a2f90fd8da3c59f816cc54c640ce265/numpy-2.3.0-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 7.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipython in ./.venv/lib/python3.13/site-packages (9.3.0)
# Collecting aiohttp>=3.11.13 (from akshare)
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/34/3f/6b7d336663337672d29b1f82d1f252ec1a040fe2d548f709d3f90fa2218a/aiohttp-3.12.13-cp313-cp313-macosx_11_0_arm64.whl (464 kB)
# Collecting beautifulsoup4>=4.9.1 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/50/cd/30110dc0ffcf3b131156077b90e9f60ed75711223f306da4db08eff8403b/beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Collecting lxml>=4.2.1 (from akshare)
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/87/cb/2ba1e9dd953415f58548506fa5549a7f373ae55e80c61c9041b7fd09a38a/lxml-5.4.0-cp313-cp313-macosx_10_13_universal2.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 8.6 MB/s eta 0:00:00a 0:00:01m
# Collecting requests>=2.22.0 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/7c/e4/56027c4a6b4ae70ca9de302488c5ca95ad4a39e190093d6c1a8ace08341b/requests-2.32.4-py3-none-any.whl (64 kB)
# Collecting html5lib>=1.0.1 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/6c/dd/a834df6482147d48e225a49515aabc28974ad5a4ca3215c18a882565b028/html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting xlrd>=1.2.0 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/1a/62/c8d562e7766786ba6587d09c5a8ba9f718ed3fa8af7f4553e8f91c36f302/xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Collecting urllib3>=1.25.8 (from akshare)
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/a7/c2/fe1e52489ae3122415c51f387e221dd0773709bad6c6cdaa599e8a2c5185/urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting tqdm>=4.43.0 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting openpyxl>=3.0.3 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Collecting jsonpath>=0.82 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/cf/a1/693351acd0a9edca4de9153372a65e75398898ea7f8a5c722ab00f464929/jsonpath-0.82.2.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tabulate>=0.8.6 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: decorator>=4.4.2 in ./.venv/lib/python3.13/site-packages (from akshare) (5.2.1)
# Requirement already satisfied: nest_asyncio>=1.6.0 in ./.venv/lib/python3.13/site-packages (from akshare) (1.6.0)
# Collecting mini-racer>=0.12.4 (from akshare)
#   Using cached https://mirror.nju.edu.cn/pypi/web/packages/99/ae/c22478eff26e6136341e6b40d34f8d285f910ca4d2e2a0ca4703ef87be79/mini_racer-0.12.4-py3-none-macosx_11_0_arm64.whl (14.6 MB)
# Collecting matplotlib>=3.0.0 (from quantstats-reloaded)
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/6c/0c/02f1c3b66b30da9ee343c343acbb6251bef5b01d34fad732446eaadcd108/matplotlib-3.10.3-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 6.9 MB/s eta 0:00:00a 0:00:01
# Collecting scipy>=1.2.0 (from quantstats-reloaded)
#   Downloading https://mirror.nju.edu.cn/pypi/web/packages/5b/d8/59e452c0a255ec352bd0a833537a3bc1bfb679944c4938ab375b0a6b3a3e/scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl (22.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 12.8/22.4 MB 5.0 MB/s eta 0:00:02
# error: incomplete-download
#
# × Download failed because not enough bytes were received (12.8 MB/22.4 MB)
# ╰─> URL: https://mirror.nju.edu.cn/pypi/web/packages/5b/d8/59e452c0a255ec352bd0a833537a3bc1bfb679944c4938ab375b0a6b3a3e/scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl#sha256=8c9ed3ba2c8a2ce098163a9bdb26f891746d02136995df25227a20e71c396ebb
#
# note: This is an issue with network connectivity, not pip.
# hint: Consider using --resume-retries to enable download resumption.
# Note: you may need to restart the kernel to use updated packages.

# %%
# ----------------------------------------------------------------------------------
# 实战项目: 智能定投结合止盈的基金交易策略
# ----------------------------------------------------------------------------------

import backtrader as bt
import akshare as ak
import pandas as pd
import quantstats as qs

# ==================================================================================
# 第1步：参数配置
# ==================================================================================
# --- 基础配置 ---
FUND_SYMBOL = '001632'          # 基金代码
BENCHMARK_SYMBOL = 'sh000300'   # 基准指数代码
START_DATE = '20180101'         # 回测开始日期
END_DATE = '20241231'           # 回测结束日期
INITIAL_CASH = 100000.0         # 初始资金
COMMISSION_RATE = 0.0015        # 手续费率

# --- 新策略参数 ---
TAKE_PROFIT_PCT = 0.20            # 止盈触发收益率 (例如: 20%)
INVESTMENT_DAY = 1                # 每月定投日 (例如: 1号)
BASE_INVESTMENT_AMOUNT = 5000.0   # 单次定投基础金额
BASELINE_MA_PERIOD = 20          # 用于判断高低点的基准移动平均线周期 (例如: 半年线)

# ==================================================================================
# 第2步：数据获取与整合 (代码与之前版本相同)
# ==================================================================================
def get_fund_and_benchmark_data(fund_symbol, benchmark_symbol, start, end):
    print("开始下载基金和基准数据...")
    try:
        fund_nav_df = ak.fund_open_fund_info_em(symbol=fund_symbol, indicator="单位净值走势")
        fund_nav_df['净值日期'] = pd.to_datetime(fund_nav_df['净值日期'])
        fund_nav_df = fund_nav_df.set_index('净值日期')
        fund_nav_df = fund_nav_df[['单位净值']]
        fund_nav_df.columns = ['close']
        fund_nav_df['close'] = pd.to_numeric(fund_nav_df['close'])
    except Exception as e:
        print(f"获取基金 {fund_symbol} 数据失败: {e}")
        return None, None
    try:
        benchmark_df = ak.stock_zh_index_daily(symbol=benchmark_symbol)
        benchmark_df['date'] = pd.to_datetime(benchmark_df['date'])
        benchmark_df = benchmark_df.set_index('date')
        benchmark_df = benchmark_df[['close']]
    except Exception as e:
        print(f"获取基准 {benchmark_symbol} 数据失败: {e}")
        return None, None
    
    data = fund_nav_df.copy().sort_index()
    data['open'] = data['high'] = data['low'] = data['close']
    data['volume'] = 1000
    data['openinterest'] = 0
    data = data[start:end]
    benchmark_df = benchmark_df[start:end]
    print("数据下载和整合完成。")
    return data, benchmark_df['close']

# ==================================================================================
# 第3步：全新策略 - 智能定投与止盈策略
# ==================================================================================
class SmartAciAndTakeProfitStrategy(bt.Strategy):
    params = (
        ('take_profit_pct', TAKE_PROFIT_PCT),
        ('investment_day', INVESTMENT_DAY),
        ('base_investment', BASE_INVESTMENT_AMOUNT),
        ('ma_period', BASELINE_MA_PERIOD),
    )

    def __init__(self):
        # 定义判断市场高低位的基准线
        self.ma_baseline = bt.indicators.SimpleMovingAverage(self.data.close, period=self.p.ma_period)
        
        # 订单跟踪
        self.order = None
        
        # 记录上一个定投的月份，防止一个月内重复投资
        self.last_investment_month = -1

    def notify_order(self, order):
        # (这部分代码与之前相同，用于打印交易日志)
        if order.status in [order.Submitted, order.Accepted]:
            return
        if order.status in [order.Completed]:
            if order.isbuy():
                print(
                    f"\n--- 交易执行 ---\n"
                    f"日期: {self.data.datetime.date(0)}\n"
                    f"操作: 定投买入 (BUY)\n"
                    f"成交份额: {order.executed.size:.2f}, 价格: {order.executed.price:.4f}\n"
                    f"交易金额: {order.executed.value:.2f}, 手续费: {order.executed.comm:.2f}\n"
                    f"-----------------"
                )
            elif order.issell():
                print(
                    f"\n--- 交易执行 ---\n"
                    f"日期: {self.data.datetime.date(0)}\n"
                    f"操作: 止盈卖出 (SELL)\n"
                    f"成交份额: {order.executed.size:.2f}, 价格: {order.executed.price:.4f}\n"
                    f"交易金额: {order.executed.value:.2f}, 手续费: {order.executed.comm:.2f}\n"
                    f"-----------------"
                )
            self.order = None
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            print(f"xx 订单失败/取消: {order.getstatusname()} xx")
            self.order = None

    def next(self):
        # 如果有订单正在处理，则等待
        if self.order:
            return

        # 1. 检查是否需要止盈 (如果持有仓位)
        if self.position:
            # 计算当前持仓的收益率
            # self.position.price 是买入的平均成本价
            # self.data.close[0] 是当前的价格
            profit_pct = (self.data.close[0] - self.position.price) / self.position.price
            
            if profit_pct >= self.p.take_profit_pct:
                print(f"\n{self.data.datetime.date()}: 达到 {self.p.take_profit_pct*100:.0f}% 止盈点 (当前收益率 {profit_pct*100:.2f}%)，准备卖出。")
                self.order = self.close() # 卖出全部仓位
                return # 卖出后，本周期不再做其他操作

        # 2. 检查是否是定投日，并且执行智能定投 (如果当前没有持仓)
        # 注意：这里的逻辑是止盈后，会空仓等待下一次买入机会
        if not self.position:
            current_date = self.data.datetime.date()
            current_month = current_date.month
            
            # 判断是否是新的月份的定投时点
            # 1. 月份和上次投资月份不同
            # 2. 日期大于等于设定的定投日 (为了处理节假日，找到当月第一个可交易日)
            if current_month != self.last_investment_month and current_date.day >= self.p.investment_day:
                
                # 更新投资月份，确保本月只投一次
                self.last_investment_month = current_month
                
                # 智能定投的核心判断：当前价格是否低于基准线
                if self.data.close[0] < self.ma_baseline[0]:
                    print(f"\n{current_date}: 到达定投日，且价格低于基准线，准备买入。")
                    
                    # 计算要买入的份额
                    size_to_buy = self.p.base_investment / self.data.close[0]
                    self.order = self.buy(size=size_to_buy)
                else:
                    print(f"\n{current_date}: 到达定投日，但价格高于基准线，本月不投。")

    def stop(self):
        # (这部分代码与之前相同，用于生成报告)
        print("\n回测结束，正在生成绩效报告...")
        global benchmark_data
        time_return_analyzer = self.analyzers.getbyname('time_return')
        returns_dict = time_return_analyzer.get_analysis()
        returns = pd.Series(returns_dict)
        if returns.index.tz is not None:
            returns.index = returns.index.tz_localize(None)
        benchmark_rets = benchmark_data.pct_change().dropna()
        report_filename = f'strategy_report_{FUND_SYMBOL}_smart_aci.html'
        try:
            qs.reports.html(returns, benchmark=benchmark_rets, output=report_filename, 
                            title=f'{FUND_SYMBOL} - 智能定投与止盈策略 vs. 基准指数')
            print(f"绩效报告已成功生成：{report_filename}")
        except Exception as e:
            print(f"生成 quantstats 报告时出错: {e}")

# ==================================================================================
# 第4步：回测引擎
# ==================================================================================
if __name__ == '__main__':
    fund_data, benchmark_data = get_fund_and_benchmark_data(FUND_SYMBOL, BENCHMARK_SYMBOL, START_DATE, END_DATE)

    if fund_data is not None and not fund_data.empty:
        cerebro = bt.Cerebro()
        
        data_feed = bt.feeds.PandasData(dataname=fund_data, name=FUND_SYMBOL)
        cerebro.adddata(data_feed)
        
        # 添加我们新的策略
        cerebro.addstrategy(SmartAciAndTakeProfitStrategy)
        
        # 设置初始资金和手续费
        cerebro.broker.setcash(INITIAL_CASH)
        cerebro.broker.setcommission(commission=COMMISSION_RATE)
        
        # 注意：这里不再使用Sizer，因为我们是按固定金额定投，在策略内部计算份额
        
        cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='time_return')
        
        print("\n开始执行回测...")
        results = cerebro.run()
        
        final_value = cerebro.broker.getvalue()
        print("\n--- 回测完成 ---")
        print(f"初始资产: {INITIAL_CASH:,.2f}")
        print(f"最终资产: {final_value:,.2f}")
        print("详细的绩效分析请打开生成的HTML报告文件查看。")
    else:
        print("未能获取到数据，回测中止。")
# Out:
# 开始下载基金和基准数据...
# 数据下载和整合完成。
#
# 开始执行回测...
#
# 2018-01-29: 到达定投日，且价格低于基准线，准备买入。
#
# --- 交易执行 ---
# 日期: 2018-01-30
# 操作: 定投买入 (BUY)
# 成交份额: 3289.04, 价格: 1.5145
# 交易金额: 4981.25, 手续费: 7.47
# -----------------
#
# 2019-07-02: 达到 20% 止盈点 (当前收益率 20.05%)，准备卖出。
#
# --- 交易执行 ---
# 日期: 2019-07-03
# 操作: 止盈卖出 (SELL)
# 成交份额: -3289.04, 价格: 1.7906
# 交易金额: 4981.25, 手续费: 8.83
# -----------------
#
# 2019-07-03: 到达定投日，但价格高于基准线，本月不投。
#
# 2019-08-01: 到达定投日，且价格低于基准线，准备买入。
#
# --- 交易执行 ---
# 日期: 2019-08-02
# 操作: 定投买入 (BUY)
# 成交份额: 2960.33, 价格: 1.6765
# 交易金额: 4963.00, 手续费: 7.44
# -----------------
#
# 2020-05-08: 达到 20% 止盈点 (当前收益率 20.52%)，准备卖出。
#
# --- 交易执行 ---
# 日期: 2020-05-11
# 操作: 止盈卖出 (SELL)
# 成交份额: -2960.33, 价格: 2.0077
# 交易金额: 4963.00, 手续费: 8.92
# -----------------
#
# 2020-05-11: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-06-01: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-07-01: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-08-03: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-09-01: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-10-09: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-11-02: 到达定投日，但价格高于基准线，本月不投。
#
# 2020-12-01: 到达定投日，且价格低于基准线，准备买入。
#
# --- 交易执行 ---
# 日期: 2020-12-02
# 操作: 定投买入 (BUY)
# 成交份额: 1645.49, 价格: 3.0413
# 交易金额: 5004.44, 手续费: 7.51
# -----------------
#
# 2021-01-05: 达到 20% 止盈点 (当前收益率 24.86%)，准备卖出。
#
# --- 交易执行 ---
# 日期: 2021-01-06
# 操作: 止盈卖出 (SELL)
# 成交份额: -1645.49, 价格: 3.8144
# 交易金额: 5004.44, 手续费: 9.41
# -----------------
#
# 2021-01-06: 到达定投日，但价格高于基准线，本月不投。
#
# 2021-02-01: 到达定投日，且价格低于基准线，准备买入。
#
# --- 交易执行 ---
# 日期: 2021-02-02
# 操作: 定投买入 (BUY)
# 成交份额: 1410.99, 价格: 3.6672
# 交易金额: 5174.40, 手续费: 7.76
# -----------------
#
# 回测结束，正在生成绩效报告...
# 绩效报告已成功生成：strategy_report_001632_smart_aci.html
#
# --- 回测完成 ---
# 初始资产: 100,000.00
# 最终资产: 101,069.97
# 详细的绩效分析请打开生成的HTML报告文件查看。
# c:\Users\zhang\Documents\Code\python\fund\.venv\Lib\site-packages\quantstats\_plotting\core.py:1016: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   port["Weekly"].ffill(inplace=True)
# c:\Users\zhang\Documents\Code\python\fund\.venv\Lib\site-packages\quantstats\_plotting\core.py:1019: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   port["Monthly"].ffill(inplace=True)
# c:\Users\zhang\Documents\Code\python\fund\.venv\Lib\site-packages\quantstats\_plotting\core.py:1022: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   port["Quarterly"].ffill(inplace=True)
# c:\Users\zhang\Documents\Code\python\fund\.venv\Lib\site-packages\quantstats\_plotting\core.py:1025: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   port["Yearly"].ffill(inplace=True)

# %% [markdown]
# 现在，这是我们的“实战决策”脚本：

# %%
# ----------------------------------------------------------------------------------
# 实战应用: RSI相对强弱指数策略 - 每日决策脚本 (无 pandas_ta 依赖)
# ----------------------------------------------------------------------------------

import akshare as ak
import pandas as pd
from datetime import datetime, timedelta

# ==================================================================================
# 1. 参数配置 (与回测时保持一致)
# ==================================================================================
FUND_SYMBOL = '001749'          # 你要操作的基金代码

# --- RSI策略参数 ---
RSI_PERIOD = 14                   # RSI的计算周期
RSI_UPPER = 70.0                  # RSI超买阈值 (触发卖出)
RSI_LOWER = 30.0                  # RSI超卖阈值 (触发买入)

# ==================================================================================
# 2. 数据获取函数 (与之前相同)
# ==================================================================================
def get_latest_fund_data(fund_symbol):
    print(f"正在获取基金 {fund_symbol} 的最新净值数据...")
    
    # 为了计算14日的RSI，我们至少需要100天的数据作为缓冲
    start_date = (datetime.today() - timedelta(days=100)).strftime('%Y%m%d')
    
    try:
        fund_nav_df = ak.fund_open_fund_info_em(symbol=fund_symbol, indicator="单位净值走势")
        fund_nav_df['净值日期'] = pd.to_datetime(fund_nav_df['净值日期'])
        fund_nav_df = fund_nav_df.set_index('净值日期')
        fund_nav_df = fund_nav_df[['单位净值']]
        fund_nav_df.columns = ['close']
        fund_nav_df['close'] = pd.to_numeric(fund_nav_df['close'])
        
        fund_nav_df = fund_nav_df[start_date:]
        
        if fund_nav_df.empty:
            print("错误：获取到的数据为空，请检查基金代码或网络。")
            return None
            
        print("数据获取成功！")
        return fund_nav_df
        
    except Exception as e:
        print(f"获取基金 {fund_symbol} 数据时发生错误: {e}")
        return None

# ==================================================================================
# 3. 自定义RSI计算函数
# ==================================================================================
def calculate_rsi(data, period):
    """
    使用 pandas 手动计算 RSI 指标。
    :param data: 一个包含 'close' 列的 pandas DataFrame。
    :param period: RSI的计算周期。
    :return: 带有 'rsi' 列的 DataFrame。
    """
    # 步骤1：计算每日价格变化
    delta = data['close'].diff()

    # 步骤2：分离上涨和下跌
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)

    # 步骤3：计算上涨和下跌的指数移动平均 (EMA)
    # pandas 的 ewm 方法提供了计算EMA的功能。
    # com (center of mass) 是另一种表示 alpha 的方式, com = 1/alpha - 1
    # 对于RSI，通常使用 alpha = 1/period，所以 com = period - 1
    ema_up = up.ewm(com=period - 1, adjust=False).mean()
    ema_down = down.ewm(com=period - 1, adjust=False).mean()

    # 步骤4：计算相对强度 (RS)
    rs = ema_up / ema_down

    # 步骤5：计算RSI
    data['rsi'] = 100 - (100 / (1 + rs))
    
    return data

# ==================================================================================
# 4. 主程序：分析并给出决策
# ==================================================================================
if __name__ == '__main__':
    # 获取数据
    df = get_latest_fund_data(FUND_SYMBOL)

    if df is not None:
        # 使用我们自己的函数计算RSI
        df_with_rsi = calculate_rsi(df, period=RSI_PERIOD)
        
        # 提取最新的数据
        latest_data = df_with_rsi.iloc[-1]
        latest_date = latest_data.name.strftime('%Y-%m-%d')
        latest_close = latest_data['close']
        latest_rsi = latest_data['rsi'] # 获取最新RSI值
        
        # --- 核心决策逻辑 ---
        action = "持有/观望" # 默认操作
        reason = f"RSI ({latest_rsi:.2f}) 处于 {RSI_LOWER} 和 {RSI_UPPER} 之间的中间区域。"

        if latest_rsi <= RSI_LOWER:
            action = "买入"
            reason = f"RSI ({latest_rsi:.2f}) 进入超卖区 (<= {RSI_LOWER})，是潜在的买入时机。"
        elif latest_rsi >= RSI_UPPER:
            action = "卖出"
            reason = f"RSI ({latest_rsi:.2f}) 进入超买区 (>= {RSI_UPPER})，是潜在的卖出时机。"
            
        # --- 清晰地打印决策结果 ---
        print("\n==================================================")
        print(f"       基金 {FUND_SYMBOL} - RSI策略每日决策           ")
        print("==================================================")
        print(f"数据更新至: {latest_date}")
        print(f"最新净值:   {latest_close:.4f}")
        print(f"最新RSI({RSI_PERIOD}日): {latest_rsi:.2f}")
        print("--------------------------------------------------")
        print(f"策略建议:   {action}")
        print(f"决策理由:   {reason}")
        print("==================================================")
        print("\n*免责声明：本程序仅为量化策略学习工具，不构成任何投资建议。")
# Out:
# 正在获取基金 001749 的最新净值数据...
# 数据获取成功！
#
# ==================================================
#        基金 001749 - RSI策略每日决策
# ==================================================
# 数据更新至: 2025-06-18
# 最新净值:   1.3520
# 最新RSI(14日): 51.46
# --------------------------------------------------
# 策略建议:   持有/观望
# 决策理由:   RSI (51.46) 处于 30.0 和 70.0 之间的中间区域。
# ==================================================
#
# *免责声明：本程序仅为量化策略学习工具，不构成任何投资建议。
